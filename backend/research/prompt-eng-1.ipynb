# %%
OLLAMA_BASE_URL="https://61d7-107-20-19-92.ngrok-free.app"
OLLAMA_MODEL="llama3"

# %% [markdown]
# # Setup LLM

# %%
from langchain_community.chat_models import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatOllama(model=OLLAMA_MODEL, base_url=OLLAMA_BASE_URL)
prompt = ChatPromptTemplate.from_template("Tell me three things you like about {topic}")

chain = prompt | llm | StrOutputParser()

async for chunk in chain.astream({"topic": "Cars"}):
    print(chunk)
# Out:
# A
#  fun
#  question
# !
#
#
# Here
#  are
#  three
#  things
#  I
#  like
#  about
#  Cars
# :
#
#
# 1
# .
#  **
# Light
# ning
#  Mc
# Queen
# **:
#  He
# 's
#  a
#  lo
# vable
#  and
#  memorable
#  character
# !
#  His
#  antics
# ,
#  humor
# ,
#  and
#  friendship
#  with
#  Mater
#  make
#  him
#  a
#  joy
#  to
#  watch
# .
#
# 2
# .
#  **
# The
#  World
#  of
#  Radi
# ator
#  Springs
# **:
#  The
#  small
#  town
#  setting
# ,
#  filled
#  with
#  quirky
#  characters
#  and
#  nostalgic
#  charm
# ,
#  provides
#  a
#  delightful
#  backdrop
#  for
#  the
#  adventures
#  in
#  Cars
# .
#
# 3
# .
#  **
# The
#  Attention
#  to
#  Detail
# **:
#  The
#  film
# 's
#  animation
#  and
#  design
#  are
#  incredibly
#  detailed
# ,
#  making
#  it
#  easy
#  to
#  get
#  lost
#  in
#  the
#  world
#  of
#  Cars
# .
#  From
#  the
#  realistic
#  car
#  designs
#  to
#  the
#  beautiful
#  landscapes
# ,
#  there
# 's
#  plenty
#  to
#  appreciate
# !
#
#
# What
#  about
#  you
# ?
#  What
#  do
#  you
#  like
#  most
#  about
#  Cars
# ?
